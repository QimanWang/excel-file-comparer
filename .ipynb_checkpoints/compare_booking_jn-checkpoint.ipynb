# %%
import pandas as pd

# %%
xl = pd.ExcelFile("30031-GuestListDetailed cancel 7.1-8.13.xlsx")
canceled_df = xl.parse("Sheet1",header=2,index_col=0,keep_default_na = False)
print(list(canceled_df))
# Out:
# ['Name', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Level', 'Unnamed: 7', 'Unnamed: 8', 'Room Type', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Room', 'Unnamed: 14', 'Source', 'Unnamed: 16', 'Unnamed: 17', 'Acct#', 'Unnamed: 19', 'Unnamed: 20', 'CRS#', 'Unnamed: 22', 'Unnamed: 23', 'Status', 'Unnamed: 25', 'Arrival', 'Unnamed: 27', 'Unnamed: 28', 'Departure', 'Unnamed: 30', 'Unnamed: 31', 'Adult/Child', 'GTD', 'Unnamed: 34', 'Rate', 'Unnamed: 36', 'Unnamed: 37', 'Rate Plan', 'Unnamed: 39', 'Unnamed: 40', 'Balance', 'Unnamed: 42', 'Unnamed: 43']

# %%
for index, row in canceled_df.iterrows():
    if index =='':
        print("index:::",index,row['Rate'])
# Out:
# index:::  $94.25
# index:::
# index:::  $135.20
# index:::
# index:::  $102.26
# index:::
# index:::
# index:::
# index:::
# index:::  $114.00
# index:::
# index:::
# index:::
# index:::  $152.88
# index:::
# index:::
# index:::  $73.37
# index:::
# index:::
# index:::  $113.65
# index:::
# index:::
# index:::  $75.70
# index:::
# index:::
# index:::
# index:::
# index:::
# index:::  Rate
# index:::
# index:::
# index:::
# index:::  $81.43
# index:::
# index:::
# index:::  $151.20
# index:::
# index:::
# index:::  $103.20
# index:::
# index:::
# index:::
# index:::
# index:::  $98.94
# index:::
# index:::
# index:::  $136.89
# index:::
# index:::  $101.68
# index:::
# index:::
# index:::
# index:::
# index:::
# index:::
# index:::
# index:::
# index:::  Rate
# index:::  $90.00
# index:::
# index:::  $126.92
# index:::
# index:::
# index:::  $126.02
# index:::
# index:::
# index:::  $116.12
# index:::
# index:::
# index:::
# index:::  $124.00
# index:::
# index:::
# index:::  $66.38
# ...

# %%
df = canceled_df

# %%
df.loc[(df['Name']!="") & (df['Name']!="Name") ]
# Out:
#                               Name Unnamed: 1 Unnamed: 2 Unnamed: 3  \
#                          ABDULLAH,
#                           MOHAMMED
#                        ABU, GODWIN
#                            OWOICHO
#                    AHMAD, FAATIMAH
#                        AHMED, SYED
#                     ALAQUINEZ, JOE
#                      ALI, MOHAMMAD
#                    ALLEN, ANGELICA
#                    ALLEN, MICHELLE
#     30031 - DAYS INN PHILADELPHIA.
#                  Guest List Detail
#                     ALONSO, VICTOR
#                    ALONZO, ANTHONY
#                  ALSHAMRANI, BASIM
#                    ALVARADO, MARIA
#                         AL-ZAGHAL,
#                           ABDULLAH
#                         AMIN, NEEL
#     30031 - DAYS INN PHILADELPHIA.
#                  Guest List Detail
#                   ANDERSON, LOUISE
#                  ANGUIANO JR, JOSE
#                  ANTHONY, MARGARET
#                  AOUSSIM, MUSTAPHA
# ...
